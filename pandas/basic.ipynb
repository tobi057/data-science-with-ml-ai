# %%
# !pip install pandas
# Out:
# ...
# [notice] A new release of pip is available: 23.2.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd

# %%
df =pd.read_csv('Used_Bikes.csv')  ## path

# %%
df
# Out:
#                                   bike_name     price       city  kms_driven  \
# 0        TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1               Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                      Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                      TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4      Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# ...                                     ...       ...        ...         ...
# 32643                Hero Passion Pro 100cc   39000.0      Delhi     22000.0
# 32644                  TVS Apache RTR 180cc   30000.0     Karnal      6639.0
# 32645              Bajaj Avenger Street 220   60000.0      Delhi     20373.0
# 32646             Hero Super Splendor 125cc   15600.0     Jaipur     84186.0
# 32647                    Bajaj Pulsar 150cc   22000.0       Pune     60857.0
#
# ...

# %%
df.head() ## head uper ke 5 element
# Out:
#                               bike_name     price       city  kms_driven  \
# 0    TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1           Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                  Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                  TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4  Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
#
#          owner  age  power          brand
# 0  First Owner  3.0  110.0            TVS
# 1  First Owner  4.0  350.0  Royal Enfield
# 2  First Owner  8.0  675.0        Triumph
# 3  First Owner  4.0  180.0            TVS
# 4  First Owner  3.0  150.0         Yamaha

# %%
df.tail()
# Out:
#                        bike_name    price    city  kms_driven        owner  \
# 32643     Hero Passion Pro 100cc  39000.0   Delhi     22000.0  First Owner
# 32644       TVS Apache RTR 180cc  30000.0  Karnal      6639.0  First Owner
# 32645   Bajaj Avenger Street 220  60000.0   Delhi     20373.0  First Owner
# 32646  Hero Super Splendor 125cc  15600.0  Jaipur     84186.0  First Owner
# 32647         Bajaj Pulsar 150cc  22000.0    Pune     60857.0  First Owner
#
#         age  power  brand
# 32643   4.0  100.0   Hero
# 32644   9.0  180.0    TVS
# 32645   6.0  220.0  Bajaj
# 32646  16.0  125.0   Hero
# 32647  13.0  150.0  Bajaj

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32648 entries, 0 to 32647
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   bike_name   32648 non-null  object
#  1   price       32648 non-null  float64
#  2   city        32648 non-null  object
#  3   kms_driven  32648 non-null  float64
#  4   owner       32648 non-null  object
#  5   age         32648 non-null  float64
#  6   power       32648 non-null  float64
#  7   brand       32648 non-null  object
# dtypes: float64(4), object(4)
# memory usage: 2.0+ MB

# %%
df.columns
# Out:
# Index(['bike_name', 'price', 'city', 'kms_driven', 'owner', 'age', 'power',
#        'brand'],
#       dtype='object')

# %%
df.describe()
# Out:
#               price     kms_driven           age         power
# count  3.264800e+04   32648.000000  32648.000000  32648.000000
# mean   6.829542e+04   26344.625184      8.048211    213.511302
# std    9.071860e+04   22208.527695      4.031700    134.428868
# min    4.400000e+03       1.000000      1.000000    100.000000
# 25%    2.500000e+04   12000.000000      5.000000    150.000000
# 50%    4.300000e+04   20373.000000      7.000000    150.000000
# 75%    8.000000e+04   35000.000000     10.000000    220.000000
# max    1.900000e+06  750000.000000     63.000000   1800.000000

# %%
df.isnull()
# Out:
#        bike_name  price   city  kms_driven  owner    age  power  brand
# 0          False  False  False       False  False  False  False  False
# 1          False  False  False       False  False  False  False  False
# 2          False  False  False       False  False  False  False  False
# 3          False  False  False       False  False  False  False  False
# 4          False  False  False       False  False  False  False  False
# ...          ...    ...    ...         ...    ...    ...    ...    ...
# 32643      False  False  False       False  False  False  False  False
# 32644      False  False  False       False  False  False  False  False
# 32645      False  False  False       False  False  False  False  False
# 32646      False  False  False       False  False  False  False  False
# 32647      False  False  False       False  False  False  False  False
#
# [32648 rows x 8 columns]

# %%
df.isnull().sum()
# Out:
# bike_name     0
# price         0
# city          0
# kms_driven    0
# owner         0
# age           0
# power         0
# brand         0
# dtype: int64

# %%
df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 32643     True
# 32644     True
# 32645     True
# 32646     True
# 32647     True
# Length: 32648, dtype: bool

# %%
df.duplicated().sum()
# Out:
# np.int64(25324)

# %%
df.drop_duplicates(inplace=True) ###

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# df.dropna()
df
# Out:
#                                  bike_name     price       city  kms_driven  \
# 0       TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1              Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                     Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                     TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4     Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# ...                                    ...       ...        ...         ...
# 9362             Hero Hunk Rear Disc 150cc   25000.0      Delhi     48587.0
# 9369                   Bajaj Avenger 220cc   35000.0  Bangalore     60000.0
# 9370        Harley-Davidson Street 750 ABS  450000.0    Jodhpur      3430.0
# 9371                 Bajaj Dominar 400 ABS  139000.0  Hyderabad     21300.0
# 9372              Bajaj Avenger Street 220   80000.0  Hyderabad      7127.0
#
#             owner  age  power            brand
# ...

# %%
df['bike_name']
# Out:
# 0         TVS Star City Plus Dual Tone 110cc
# 1                Royal Enfield Classic 350cc
# 2                       Triumph Daytona 675R
# 3                       TVS Apache RTR 180cc
# 4       Yamaha FZ S V 2.0 150cc-Ltd. Edition
#                         ...
# 9362               Hero Hunk Rear Disc 150cc
# 9369                     Bajaj Avenger 220cc
# 9370          Harley-Davidson Street 750 ABS
# 9371                   Bajaj Dominar 400 ABS
# 9372                Bajaj Avenger Street 220
# Name: bike_name, Length: 7324, dtype: object

# %%
df['brand']
# Out:
# 0                   TVS
# 1         Royal Enfield
# 2               Triumph
# 3                   TVS
# 4                Yamaha
#              ...
# 9362               Hero
# 9369              Bajaj
# 9370    Harley-Davidson
# 9371              Bajaj
# 9372              Bajaj
# Name: brand, Length: 7324, dtype: object

# %%
df['brand'].unique()
# Out:
# array(['TVS', 'Royal Enfield', 'Triumph', 'Yamaha', 'Honda', 'Hero',
#        'Bajaj', 'Suzuki', 'Benelli', 'KTM', 'Mahindra', 'Kawasaki',
#        'Ducati', 'Hyosung', 'Harley-Davidson', 'Jawa', 'BMW', 'Indian',
#        'Rajdoot', 'LML', 'Yezdi', 'MV', 'Ideal'], dtype=object)

# %%
df['owner'].unique()
# Out:
# array(['First Owner', 'Second Owner', 'Third Owner',
#        'Fourth Owner Or More'], dtype=object)

# %%
df['brand'].nunique()
# Out:
# 23

# %%
df['brand'].value_counts()
# Out:
# brand
# Bajaj              2081
# Royal Enfield      1346
# Hero               1142
# Honda               676
# Yamaha              651
# TVS                 481
# KTM                 375
# Suzuki              203
# Harley-Davidson      91
# Kawasaki             61
# Hyosung              53
# Mahindra             50
# Benelli              46
# Triumph              21
# Ducati               20
# BMW                  10
# Jawa                  7
# Indian                3
# MV                    3
# Rajdoot               1
# LML                   1
# Yezdi                 1
# Ideal                 1
# Name: count, dtype: int64

# %%
df['owner'].value_counts()
# Out:
# owner
# First Owner             6642
# Second Owner             588
# Third Owner               84
# Fourth Owner Or More      10
# Name: count, dtype: int64

# %%
df
# Out:
#                                  bike_name     price       city  kms_driven  \
# 0       TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1              Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                     Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                     TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4     Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# ...                                    ...       ...        ...         ...
# 9362             Hero Hunk Rear Disc 150cc   25000.0      Delhi     48587.0
# 9369                   Bajaj Avenger 220cc   35000.0  Bangalore     60000.0
# 9370        Harley-Davidson Street 750 ABS  450000.0    Jodhpur      3430.0
# 9371                 Bajaj Dominar 400 ABS  139000.0  Hyderabad     21300.0
# 9372              Bajaj Avenger Street 220   80000.0  Hyderabad      7127.0
#
#             owner  age  power            brand
# ...

# %%
df =df.drop(['city','bike_name'], axis=1 )

# %%
df
# Out:
#          price  kms_driven        owner  age  power            brand
# 0      35000.0     17654.0  First Owner  3.0  110.0              TVS
# 1     119900.0     11000.0  First Owner  4.0  350.0    Royal Enfield
# 2     600000.0       110.0  First Owner  8.0  675.0          Triumph
# 3      65000.0     16329.0  First Owner  4.0  180.0              TVS
# 4      80000.0     10000.0  First Owner  3.0  150.0           Yamaha
# ...        ...         ...          ...  ...    ...              ...
# 9362   25000.0     48587.0  First Owner  8.0  150.0             Hero
# 9369   35000.0     60000.0  First Owner  9.0  220.0            Bajaj
# 9370  450000.0      3430.0  First Owner  4.0  750.0  Harley-Davidson
# 9371  139000.0     21300.0  First Owner  4.0  400.0            Bajaj
# 9372   80000.0      7127.0  First Owner  5.0  220.0            Bajaj
#
# [7324 rows x 6 columns]

# %%
cat_col =df.select_dtypes(include='object')

# %%
cat_col
# Out:
#             owner            brand
# 0     First Owner              TVS
# 1     First Owner    Royal Enfield
# 2     First Owner          Triumph
# 3     First Owner              TVS
# 4     First Owner           Yamaha
# ...           ...              ...
# 9362  First Owner             Hero
# 9369  First Owner            Bajaj
# 9370  First Owner  Harley-Davidson
# 9371  First Owner            Bajaj
# 9372  First Owner            Bajaj
#
# [7324 rows x 2 columns]

# %%
num_cal=df.select_dtypes(exclude='object')

# %%
num_cal
# Out:
#          price  kms_driven  age  power
# 0      35000.0     17654.0  3.0  110.0
# 1     119900.0     11000.0  4.0  350.0
# 2     600000.0       110.0  8.0  675.0
# 3      65000.0     16329.0  4.0  180.0
# 4      80000.0     10000.0  3.0  150.0
# ...        ...         ...  ...    ...
# 9362   25000.0     48587.0  8.0  150.0
# 9369   35000.0     60000.0  9.0  220.0
# 9370  450000.0      3430.0  4.0  750.0
# 9371  139000.0     21300.0  4.0  400.0
# 9372   80000.0      7127.0  5.0  220.0
#
# [7324 rows x 4 columns]

# %%
# bike brand = tvs 
# kms = 50000
# owner = 1st 
# power = 150cc
# age = 1 
Royal_df=df[df['brand']=='Royal Enfield']

# %%
one_royal_df=Royal_df[Royal_df['price']==100000]

# %%
km_df=one_royal_df[one_royal_df['kms_driven']==30000]

# %%
km_df
# Out:
#          price  kms_driven        owner  age  power          brand
# 6716  100000.0     30000.0  First Owner  5.0  350.0  Royal Enfield
# 7716  100000.0     30000.0  First Owner  7.0  350.0  Royal Enfield

# %%
hero_df=df[(df['brand']=='hero')&
(df['kms_driven'] == 30000)&
(df['owner'] =='2nd owner')&
(df['price'] <=50000)]

# %%
Royal_df
# Out:
#          price  kms_driven         owner   age  power          brand
# 1     119900.0     11000.0   First Owner   4.0  350.0  Royal Enfield
# 8     145000.0      9190.0   First Owner   3.0  350.0  Royal Enfield
# 9      88000.0     19000.0  Second Owner   7.0  500.0  Royal Enfield
# 23    121700.0     24520.0   First Owner   5.0  500.0  Royal Enfield
# 36     98800.0     39000.0   First Owner   5.0  350.0  Royal Enfield
# ...        ...         ...           ...   ...    ...            ...
# 9261  146006.0      8575.0   First Owner   4.0  500.0  Royal Enfield
# 9319  100000.0     25000.0   First Owner  10.0  350.0  Royal Enfield
# 9337  120000.0      8492.0   First Owner   5.0  410.0  Royal Enfield
# 9338  138000.0      5000.0   First Owner   5.0  410.0  Royal Enfield
# 9344   80000.0     56968.0   First Owner   8.0  350.0  Royal Enfield
#
# [1346 rows x 6 columns]

# %%
Hero_df=df[
(df['brand']=='Hero')&
(df['kms_driven']  == 30000)&
(df['owner'] =='Second Owner')&
(df['price'] <=50000)
]

# %%
hero_df
# Out:
# Empty DataFrame
# Columns: [price, kms_driven, owner, age, power, brand]
# Index: []

# %%
df['owner'].unique()
# Out:
# array(['First Owner', 'Second Owner', 'Third Owner',
#        'Fourth Owner Or More'], dtype=object)

# %%
owner_dict = {
    'First Owner':1, 'Second Owner':2, 'Third Owner':3,
       'Fourth Owner Or More':4
}

# %%
owner_dict
# Out:
# {'First Owner': 1,
#  'Second Owner': 2,
#  'Third Owner': 3,
#  'Fourth Owner Or More': 4}

# %%
df['owner']=df['owner'].map(owner_dict)

# %%
df.dtypes
# Out:
# price         float64
# kms_driven    float64
# owner           int64
# age           float64
# power         float64
# brand          object
# dtype: object

# %%
df.corr
# Out:
# <bound method DataFrame.corr of          price  kms_driven  owner  age  power            brand
# 0      35000.0     17654.0      1  3.0  110.0              TVS
# 1     119900.0     11000.0      1  4.0  350.0    Royal Enfield
# 2     600000.0       110.0      1  8.0  675.0          Triumph
# 3      65000.0     16329.0      1  4.0  180.0              TVS
# 4      80000.0     10000.0      1  3.0  150.0           Yamaha
# ...        ...         ...    ...  ...    ...              ...
# 9362   25000.0     48587.0      1  8.0  150.0             Hero
# 9369   35000.0     60000.0      1  9.0  220.0            Bajaj
# 9370  450000.0      3430.0      1  4.0  750.0  Harley-Davidson
# 9371  139000.0     21300.0      1  4.0  400.0            Bajaj
# 9372   80000.0      7127.0      1  5.0  220.0            Bajaj
#
# [7324 rows x 6 columns]>

# %%
x =df.drop('price',axis=1)
y =df[['price']]

# %%
x
# Out:
#       kms_driven  owner  age  power            brand
# 0        17654.0      1  3.0  110.0              TVS
# 1        11000.0      1  4.0  350.0    Royal Enfield
# 2          110.0      1  8.0  675.0          Triumph
# 3        16329.0      1  4.0  180.0              TVS
# 4        10000.0      1  3.0  150.0           Yamaha
# ...          ...    ...  ...    ...              ...
# 9362     48587.0      1  8.0  150.0             Hero
# 9369     60000.0      1  9.0  220.0            Bajaj
# 9370      3430.0      1  4.0  750.0  Harley-Davidson
# 9371     21300.0      1  4.0  400.0            Bajaj
# 9372      7127.0      1  5.0  220.0            Bajaj
#
# [7324 rows x 5 columns]

# %%
y
# Out:
#          price
# 0      35000.0
# 1     119900.0
# 2     600000.0
# 3      65000.0
# 4      80000.0
# ...        ...
# 9362   25000.0
# 9369   35000.0
# 9370  450000.0
# 9371  139000.0
# 9372   80000.0
#
# [7324 rows x 1 columns]

# %%
df['brand'].unique()
# Out:
# array(['TVS', 'Royal Enfield', 'Triumph', 'Yamaha', 'Honda', 'Hero',
#        'Bajaj', 'Suzuki', 'Benelli', 'KTM', 'Mahindra', 'Kawasaki',
#        'Ducati', 'Hyosung', 'Harley-Davidson', 'Jawa', 'BMW', 'Indian',
#        'Rajdoot', 'LML', 'Yezdi', 'MV', 'Ideal'], dtype=object)

# %%
bike_df = df[
    (df['brand'].isin(['Royal Enfield','KTM'])) &
    (df['age'] >= 3) &
    
    (df['price'] <= 100000)
]

# %%
bike_df
# Out:
#          price  kms_driven  owner   age  power          brand
# 9      88000.0     19000.0      2   7.0  500.0  Royal Enfield
# 35     70000.0    100000.0      2   8.0  200.0            KTM
# 36     98800.0     39000.0      1   5.0  350.0  Royal Enfield
# 40     70000.0     45000.0      1   8.0  350.0  Royal Enfield
# 42     78000.0      8500.0      1  13.0  350.0  Royal Enfield
# ...        ...         ...    ...   ...    ...            ...
# 9203   90000.0     44000.0      1  10.0  350.0  Royal Enfield
# 9236   95000.0     22000.0      1   8.0  350.0  Royal Enfield
# 9252  100000.0     15078.0      1   7.0  350.0  Royal Enfield
# 9319  100000.0     25000.0      1  10.0  350.0  Royal Enfield
# 9344   80000.0     56968.0      1   8.0  350.0  Royal Enfield
#
# [609 rows x 6 columns]

# %%
df['brand'].unique()
# Out:
# array(['TVS', 'Royal Enfield', 'Triumph', 'Yamaha', 'Honda', 'Hero',
#        'Bajaj', 'Suzuki', 'Benelli', 'KTM', 'Mahindra', 'Kawasaki',
#        'Ducati', 'Hyosung', 'Harley-Davidson', 'Jawa', 'BMW', 'Indian',
#        'Rajdoot', 'LML', 'Yezdi', 'MV', 'Ideal'], dtype=object)

# %%
df
# Out:
#          price  kms_driven  owner  age  power            brand
# 0      35000.0     17654.0      1  3.0  110.0              TVS
# 1     119900.0     11000.0      1  4.0  350.0    Royal Enfield
# 2     600000.0       110.0      1  8.0  675.0          Triumph
# 3      65000.0     16329.0      1  4.0  180.0              TVS
# 4      80000.0     10000.0      1  3.0  150.0           Yamaha
# ...        ...         ...    ...  ...    ...              ...
# 9362   25000.0     48587.0      1  8.0  150.0             Hero
# 9369   35000.0     60000.0      1  9.0  220.0            Bajaj
# 9370  450000.0      3430.0      1  4.0  750.0  Harley-Davidson
# 9371  139000.0     21300.0      1  4.0  400.0            Bajaj
# 9372   80000.0      7127.0      1  5.0  220.0            Bajaj
#
# [7324 rows x 6 columns]

# %%
# bike brand = Hero 
# kms = 50000
# owner = 1st 
# power = 150cc
# age = 1

Hero_df = df[
    (df['brand'] =='Hero')&
    (df['kms_driven'] == 50000)&
    (df['owner'] == 'Second Owner')&
    (df['age'] == 2)
]

# %%
Hero_df
# Out:
# Empty DataFrame
# Columns: [price, kms_driven, owner, age, power, brand]
# Index: []

# %%
Royal_df = df[
    (df['brand'] =='Royal Enfield')&
    (df['kms_driven'] == 30000)&
    (df['owner'] == 'First Owner')&
    (df['age'] == 2) 
]

# %%
Royal_df = df

# %%
df['brand'].unique()
# Out:
# array(['TVS', 'Royal Enfield', 'Triumph', 'Yamaha', 'Honda', 'Hero',
#        'Bajaj', 'Suzuki', 'Benelli', 'KTM', 'Mahindra', 'Kawasaki',
#        'Ducati', 'Hyosung', 'Harley-Davidson', 'Jawa', 'BMW', 'Indian',
#        'Rajdoot', 'LML', 'Yezdi', 'MV', 'Ideal'], dtype=object)

# %%
df['owner'].unique()
# Out:
# array([1, 2, 3, 4])

# %%
df['brand'].value_counts()
# Out:
# brand
# Bajaj              2081
# Royal Enfield      1346
# Hero               1142
# Honda               676
# Yamaha              651
# TVS                 481
# KTM                 375
# Suzuki              203
# Harley-Davidson      91
# Kawasaki             61
# Hyosung              53
# Mahindra             50
# Benelli              46
# Triumph              21
# Ducati               20
# BMW                  10
# Jawa                  7
# Indian                3
# MV                    3
# Rajdoot               1
# LML                   1
# Yezdi                 1
# Ideal                 1
# Name: count, dtype: int64

# %%
df['brand'].value_counts()
# Out:
# brand
# Bajaj              2081
# Royal Enfield      1346
# Hero               1142
# Honda               676
# Yamaha              651
# TVS                 481
# KTM                 375
# Suzuki              203
# Harley-Davidson      91
# Kawasaki             61
# Hyosung              53
# Mahindra             50
# Benelli              46
# Triumph              21
# Ducati               20
# BMW                  10
# Jawa                  7
# Indian                3
# MV                    3
# Rajdoot               1
# LML                   1
# Yezdi                 1
# Ideal                 1
# Name: count, dtype: int64

# %%
df
# Out:
#          price  kms_driven  owner  age  power            brand
# 0      35000.0     17654.0      1  3.0  110.0              TVS
# 1     119900.0     11000.0      1  4.0  350.0    Royal Enfield
# 2     600000.0       110.0      1  8.0  675.0          Triumph
# 3      65000.0     16329.0      1  4.0  180.0              TVS
# 4      80000.0     10000.0      1  3.0  150.0           Yamaha
# ...        ...         ...    ...  ...    ...              ...
# 9362   25000.0     48587.0      1  8.0  150.0             Hero
# 9369   35000.0     60000.0      1  9.0  220.0            Bajaj
# 9370  450000.0      3430.0      1  4.0  750.0  Harley-Davidson
# 9371  139000.0     21300.0      1  4.0  400.0            Bajaj
# 9372   80000.0      7127.0      1  5.0  220.0            Bajaj
#
# [7324 rows x 6 columns]

# %%
Triumph_df = df[
    (df['brand'] == 'triumph')&
    (df['kms_driven'] ==110)&
    (df['owner'] =='First Owner')&
    (df['price'] >= 600000)

]

# %%
Triumph_df
# Out:
# Empty DataFrame
# Columns: [price, kms_driven, owner, age, power, brand]
# Index: []

# %%
TVs_df = df[
    (df['brand'] =='TVS')&
    (df['kms_driven'] == 50000)&
    (df['price'] == 50000)&
    (df['owner'] == 'Second Owner')
]

# %%
TVs_df
# Out:
# Empty DataFrame
# Columns: [price, kms_driven, owner, age, power, brand]
# Index: []

# %%
df =pd.read_csv('Used_Bikes.csv')  ## path

# %%
df
# Out:
#                                   bike_name     price       city  kms_driven  \
# 0        TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1               Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                      Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                      TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4      Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# ...                                     ...       ...        ...         ...
# 32643                Hero Passion Pro 100cc   39000.0      Delhi     22000.0
# 32644                  TVS Apache RTR 180cc   30000.0     Karnal      6639.0
# 32645              Bajaj Avenger Street 220   60000.0      Delhi     20373.0
# 32646             Hero Super Splendor 125cc   15600.0     Jaipur     84186.0
# 32647                    Bajaj Pulsar 150cc   22000.0       Pune     60857.0
#
# ...

# %%
#brand = royal or ktm
# price = 100000 se uppper
# age 3 yesr +
# price min or max
# and totel bike
# home work
# ------------ 
# brand = Royal Enfield or KTM
# price >= 100000
# age >= 3 years
# show min/max price and total bikes

bike_df = df[
    (df['brand'].isin(['Royal Enfield', 'KTM'])) &
    (df['price'] >= 100000) &
    (df['age'] >= 3)
]

print("Minimum price:", bike_df['price'].min())
print("Maximum price:", bike_df['price'].max())
print("Total bikes:", bike_df.shape[0])
bike_df
# Out:
# Minimum price: 100000.0
# Maximum price: 860000.0
# Total bikes: 2577
#                                 bike_name     price       city  kms_driven  \
# 1             Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 8       Royal Enfield Thunderbird X 350cc  145000.0  Bangalore      9190.0
# 23     Royal Enfield Classic Chrome 500cc  121700.0     Kalyan     24520.0
# 33                           KTM RC 390cc  180000.0       Pune     17700.0
# 62     Royal Enfield Bullet Electra 350cc  107100.0      Delhi     15438.0
# ...                                   ...       ...        ...         ...
# 32560                        KTM RC 390cc  196700.0     Mumbai     13216.0
# 32579                        KTM RC 390cc  196700.0     Mumbai     13216.0
# 32598                        KTM RC 390cc  196700.0     Mumbai     13216.0
# 32614  Royal Enfield Bullet Electra 350cc  105000.0      Delhi     20000.0
# 32636                        KTM RC 390cc  196700.0     Mumbai     13216.0
# ...

# %%
bike_df = df[
    (df['brand'].isin(['Royal Enfield', 'KTM'])) &
    (df['price'] >= 100000) &
    (df['age'] >= 3)
]
